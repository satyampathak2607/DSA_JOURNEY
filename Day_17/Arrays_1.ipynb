# %% [markdown]
# ## Arrays_1

# %% [markdown]
# ### LARGEST_ELEMENT_IN_AN_ARRAY

# %% [markdown]
# # SIGMA METHOD🗿

# %%
nums= [55,32,-97,99,3,67]
nums.sort(reverse=True)
print(nums[0])
# Out:
# 99

# %% [markdown]
# ## CHAD METHOD🗿

# %%
nums = [55,32,-97,99,3,67]
print(max(nums))
# Out:
# 99

# %%
min(nums)
# Out:
# -97

# %% [markdown]
# ## FOR THE GEEKS

# %%
nums = [55,32,-97,99,3,67]
n = len(nums)
largest = nums[0]
for i in range(n):

    if nums[i]>largest:
        largest = nums[i]


print(largest)
# Out:
# 99

# %% [markdown]
# ## SECOND LARGEST ELEMENT

# %% [markdown]
# ## CHAD_WAY

# %%
nums.sort()
print(nums[n-2])
# Out:
# 67

# %%
nums.remove(max(nums))

max(nums)
# Out:
# 67

# %% [markdown]
# 😭😭 it works

# %%
nums = [55,32,-97,99,3,67]
def l(nums):
    n = len(nums)
    largest = nums[0]
    for i in range(n):

        if nums[i]>largest:
            largest = nums[i]
    return largest

nums.remove(l(nums))

l(nums)
# Out:
# 67

# %% [markdown]
# ## OPTIMAL

# %%
nums = nums = [55,32,-97,99,3,67]
largest = second = float('-inf')
for i in nums:
    if i> largest:
        second = largest
        largest = i
    elif i> second and i != largest:
        second = i

print (second)
# Out:
# 67
